# %%
import spacy
import nltk

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer , SnowballStemmer

stemmer = PorterStemmer()

# %%
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting", "loves", "did"]

for word in words:
    print(word, "|", stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# eat | eat
# ate | ate
# adjustable | adjust
# rafting | raft
# ability | abil
# meeting | meet
# loves | love
# did | did

# %% [markdown]
# Lemmatization

# %%
nlp = spacy.load("en_core_web_sm")


doc = nlp("eating eats eat ate adjustable rafting ability meeting better did loved")

for token in doc:
    print(token.text," | ",token.lemma_)
# Out:
# eating  |  eat
# eats  |  eat
# eat  |  eat
# ate  |  eat
# adjustable  |  adjustable
# rafting  |  raft
# ability  |  ability
# meeting  |  meeting
# better  |  well
# did  |  do
# loved  |  love

# %%
doc = nlp("Mando talked for 3 hours although talking isn't his thing")
for token in doc:
    print(token.text," | ",token.lemma_)

# %% [markdown]
# Customizing Lemmatizier

# %%
nlp.pipe_names

# %%
ar = nlp.get_pipe('attribute_ruler')

ar.add([[{"TEXT":"Bro"}],[{"TEXT":"Brah"}]],{"LEMMA":"Brother"})

doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")
for token in doc:
    print(token.text, "|", token.lemma_)

# %%
doc[6]

# %%
doc[6].lemma_

# %% [markdown]
# Exercise

# %%
from nltk.stem import PorterStemmer , SnowballStemmer

stemmer = PorterStemmer()

# %%
#using stemming in nltk
lst_words = ['running', 'painting', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']

for word in lst_words:
    print(word," | ",stemmer.stem(word))
# Out:
# running  |  run
# painting  |  paint
# walking  |  walk
# dressing  |  dress
# likely  |  like
# children  |  children
# whom  |  whom
# good  |  good
# ate  |  ate
# fishing  |  fish

# %%
#using lemmatization in spacy

doc = nlp("running painting walking dressing likely children who good ate fishing remarkable did")

for token in doc:
    print(token.text," | ",token.lemma_)
# Out:
# running  |  run
# painting  |  painting
# walking  |  walking
# dressing  |  dress
# likely  |  likely
# children  |  child
# who  |  who
# good  |  good
# ate  |  eat
# fishing  |  fishing
# remarkable  |  remarkable
# did  |  do

# %%
text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a 
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""

# %%
#using stemming in nltk

all_word_tokens = nltk.word_tokenize(text)
all_base_words = []
for token in all_word_tokens:
  base_form = stemmer.stem(token)
  all_base_words.append(base_form)

final_base_text = ' '.join(all_base_words)
print(final_base_text)
# Out:
# latha is veri multi talent girl.sh is good at mani skill like danc , run , sing , playing.sh also like eat pav bhagi . she ha a habit of fish and swim too.besid all thi , she is a wonder at cook too .

# %%
#using lemmatisation in spacy

doc = nlp(text)
all_base_words = []

for token in doc:
  base_word =  token.lemma_
  all_base_words.append(base_word)
    
final_base_text = ' '.join(all_base_words)
print(final_base_text)
# Out:
# Latha be very multi talented girl . she be good at many skill like dancing , running , singing , play . she also like eat Pav Bhagi . she have a
#  habit of fishing and swim too . besides all this , she be a wonderful at cook too .
